# %% [markdown]
# <a href="https://colab.research.google.com/github/leesolhahaha/study/blob/main/7%EC%9E%A5_%EC%A0%9C%EB%A1%9C%EC%BD%9C%EB%9D%BC%EC%99%80%EA%B8%B0%EC%98%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(8, 3),columns=['C1', 'C2', 'C3'])
df.loc[2, 'C2'] = np.nan
df.loc[3, 'C2'] = np.nan
df
# Out:
#          C1        C2        C3
# 0 -0.989335 -1.364320 -0.807859
# 1 -0.386985  0.013261  0.099478
# 2 -1.537220       NaN  0.932404
# 3 -0.751060       NaN -0.165864
# 4  0.021151  0.385392 -0.057687
# 5 -0.657934 -1.494898 -0.294731
# 6 -1.397638  0.913577  0.173075
# 7  0.517311 -1.419076 -1.392320

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C1      8 non-null      float64
#  1   C2      6 non-null      float64
#  2   C3      8 non-null      float64
# dtypes: float64(3)
# memory usage: 320.0 bytes

# %%
df.isnull().sum()
# Out:
# C1    0
# C2    2
# C3    0
# dtype: int64

# %%
data = {'학번' : range(2000, 2010), '성적' : [85, 95, 75, 70, 100, 100, 95, 85, 80, 85],'전공':['컴퓨터공학','컴퓨터공학','화학공학','기계공학','전자공학','수학교육','건축공학','항공시스템공학','컴퓨터공학',np.nan]}
df=df.astype({'학번':object})
df=pd.DataFrame(data)

# %%
df
# Out:
#      학번   성적       전공
# 0  2000   85    컴퓨터공학
# 1  2001   95    컴퓨터공학
# 2  2002   75     화학공학
# 3  2003   70     기계공학
# 4  2004  100     전자공학
# 5  2005  100     수학교육
# 6  2006   95     건축공학
# 7  2007   85  항공시스템공학
# 8  2008   80    컴퓨터공학
# 9  2009   85      NaN

# %%
df=df.astype({'학번':object})

# %%
df
# Out:
#      학번   성적       전공
# 0  2000   85    컴퓨터공학
# 1  2001   95    컴퓨터공학
# 2  2002   75     화학공학
# 3  2003   70     기계공학
# 4  2004  100     전자공학
# 5  2005  100     수학교육
# 6  2006   95     건축공학
# 7  2007   85  항공시스템공학
# 8  2008   80    컴퓨터공학
# 9  2009   85      NaN

# %%
df.describe()
# Out:
#                성적
# count   10.000000
# mean    87.000000
# std     10.327956
# min     70.000000
# 25%     81.250000
# 50%     85.000000
# 75%     95.000000
# max    100.000000

# %%
df.describe(include='object')
# Out:
#           학번     전공
# count     10      9
# unique    10      7
# top     2000  컴퓨터공학
# freq       1      3

# %%
df.hist(figsize=(20,10), grid=False, layout=(2, 4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4154c8f110>,
# ...
#       dtype=object)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 49457 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 51201 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(np.random.randn(20, 3),columns=['C1', 'C2', 'C3'])
df.loc[1,'C1']=11
df.loc[3,'C3']=-10
plt.boxplot([df['C1'],df['C3']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f415482be90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f4154831950>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f415482b8d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f4154838450>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f4154838950>,
# ...
#  'means': []}

# %%
plt.scatter(x = df['C1'], y = df['C3'])
plt.grid(True)

# %%
sns.heatmap(df.corr(), annot=True)

# %%
import pandas as pd
d=pd.DataFrame({'date':['2020-01-03', '2021-11-22', '2022-10-05'],
'name':['K', 'J', 'O']})
df=pd.to_datetime(d.date,format='%Y-%m-%d')
df
# Out:
# 0   2020-01-03
# 1   2021-11-22
# 2   2022-10-05
# Name: date, dtype: datetime64[ns]

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(15, 3),columns=['C1', 'C2', 'C3'])
df.loc[1, 'C2'] = np.nan
df.loc[3, 'C2'] = np.nan
df
df = df.fillna(0)
df
# Out:
#           C1        C2        C3
# 0   0.279839  0.304079 -0.549224
# 1   0.145360  0.000000  1.323835
# 2  -2.371709 -0.000106 -0.205865
# 3  -0.844893  0.000000 -0.414438
# 4  -1.118936 -0.356270 -1.767385
# 5  -1.131800  0.818948  0.191350
# 6  -0.421985 -0.843053  0.712462
# 7   0.174901 -0.712642 -1.704577
# 8  -0.509202  0.456113 -1.428536
# 9   0.163672  1.320118  0.124515
# 10 -0.417204  0.786428 -0.641268
# 11  0.103915 -0.726957 -2.213274
# 12 -0.260035  2.070838  0.044097
# 13 -0.838185  1.479335  1.092561
# 14 -0.621321 -0.033998  2.520200

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(15, 3),columns=['C1', 'C2', 'C3'])
df.loc[1, 'C2'] = np.nan
df.loc[3, 'C2'] = np.nan
df
df = df.fillna(df.mean())
df
# Out:
#           C1        C2        C3
# 0   0.903592  1.489286 -2.183471
# 1  -0.469284  0.338051 -1.052581
# 2  -0.323433  0.173724 -0.332736
# 3   0.827945  0.338051 -0.040223
# 4   0.451731 -1.325611  0.564322
# 5  -0.227553  0.151833  0.074076
# 6   0.105069  0.804794  0.866161
# 7   0.056019 -0.880329  0.349458
# 8  -0.249535 -0.490163 -0.795793
# 9   2.150184  1.928751 -0.587702
# 10 -0.917052  0.149380 -0.656695
# 11  0.436192 -0.273774  1.503636
# 12 -0.759411  1.971492  0.554237
# 13 -0.521971  0.870208 -0.193937
# 14 -0.171930 -0.174935  0.630302

# %%
import numpy as np
data = {'학번' : range(2000, 2010), '성적' : [85, 95, 75, 70, 100, 100, 95, 85, 80, 85],'전공':['컴퓨터공학',np.nan,np.nan,'기계공학','전자공학','수학교육','건축공학','항공시스템공학','컴퓨터공학',np.nan]}
df=pd.DataFrame(data)
df=df.fillna(df['전공'].mode()[0])
df['전공']
# Out:
# 0      컴퓨터공학
# 1      컴퓨터공학
# 2      컴퓨터공학
# 3       기계공학
# 4       전자공학
# 5       수학교육
# 6       건축공학
# 7    항공시스템공학
# 8      컴퓨터공학
# 9      컴퓨터공학
# Name: 전공, dtype: object

# %%
import numpy as np
data = {'학번' : range(2000, 2010), '성적' : [85, 95, 75, 70, 100, 100, 95, 85, 80, 85],'전공':['컴퓨터공학',np.nan,np.nan,'기계공학','전자공학','수학교육','건축공학','항공시스템공학','컴퓨터공학',np.nan]}
df=pd.DataFrame(data)
df=df.dropna()
df
# Out:
#      학번   성적       전공
# 0  2000   85    컴퓨터공학
# 3  2003   70     기계공학
# 4  2004  100     전자공학
# 5  2005  100     수학교육
# 6  2006   95     건축공학
# 7  2007   85  항공시스템공학
# 8  2008   80    컴퓨터공학

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(np.random.randn(8, 3),columns=['C1', 'C2', 'C3'])
df.loc[1,'C1']=11
df.loc[3,'C3']=-10
plt.boxplot([df['C1'],df['C2']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f41542ab190>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f41542abc10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f41542a6b90>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x7f41542b0710>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f41542b0c50>,
# ...
#  'means': []}

# %%
df[df.C1>10].index
# Out:
# Int64Index([1], dtype='int64')

# %%
df.drop(df[df.C1>10].index)
# Out:
#          C1        C2         C3
# 0  0.054312 -1.074193  -1.074925
# 2 -1.355003  0.315292  -0.475517
# 3  0.682197 -0.039638 -10.000000
# 4 -0.263734 -1.906600   0.552270
# 5  0.119409 -0.149861  -0.364986
# 6 -0.970319 -0.628781   0.699701
# 7  0.334986 -1.598839   1.350235

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.DataFrame(np.random.randn(15, 3),columns=['C1', 'C2', 'C3'])
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/빅데이터분석시각화(전공심화 1학기)/소스코드/7징/기온과제로콜라.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       366 non-null    object
#  1   mean       366 non-null    float64
#  2   min        365 non-null    float64
#  3   max        366 non-null    float64
#  4   zero_coke  366 non-null    int64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 14.4+ KB

# %%
df.head()
# Out:
#          date  mean   min   max  zero_coke
# 0  2021-09-24  21.8  16.7  26.9         58
# 1  2021-09-25  21.2  18.7  23.1         54
# 2  2021-09-26  22.6  18.4  27.3         77
# 3  2021-09-27  21.6  18.7  25.0        100
# 4  2021-09-28  21.5  19.6  24.4         77

# %%
df.isnull().sum()
# Out:
# date         0
# mean         0
# min          1
# max          0
# zero_coke    0
# dtype: int64

# %%
df.describe()
# Out:
#              mean         min         max   zero_coke
# count  366.000000  365.000000  366.000000  366.000000
# mean    13.556011    9.522466   18.236612   41.893443
# std     10.749479   11.146055   10.566594   16.789824
# min    -12.100000  -15.500000   -7.300000    6.000000
# 25%      5.025000    0.700000    9.300000   30.000000
# 50%     14.700000   10.400000   20.150000   44.000000
# 75%     22.875000   18.900000   27.275000   54.000000
# max     30.900000   27.400000   36.100000  100.000000

# %%
df=df.dropna(axis=0)
df.isnull().sum()
# Out:
# date         0
# mean         0
# min          0
# max          0
# zero_coke    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(20,10), grid=False, layout=(2, 4), bins = 30)
# Out:
# array([[<Axes: title={'center': 'mean'}>,
#         <Axes: title={'center': 'min'}>, <Axes: title={'center': 'max'}>,
#         <Axes: title={'center': 'zero_coke'}>],
#        [<Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object)

# %%
import numpy as np
num_features = df.select_dtypes(include=[np.number]).columns
sns.pairplot(df[num_features])

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df[['max','zero_coke']].corr(), annot=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-60d7d5b7aa9b> in <cell line: 2>()
#       1 plt.figure(figsize=(20,7))
# ----> 2 sns.heatmap(df[['max','zero_coke']].corr(), annot=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3765             if is_iterator(key):
#    3766                 key = list(key)
# -> 3767             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3768
#    3769         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    5875             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    5876
# -> 5877         self._raise_if_missing(keyarr, indexer, axis_name)
#    5878
#    5879         keyarr = self.take(indexer)
#
# ...

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df=pd.read_csv('/content/abalone.csv',encoding='utf-8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.mode()
# Out:
#    Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0    M   0.550      0.45    0.15        0.2225           0.175
# 1  NaN   0.625       NaN     NaN           NaN             NaN
#
#    Viscera weight  Shell weight  Rings
# 0          0.1715         0.275    9.0
# 1             NaN           NaN    NaN

# %%
df=df[df.Height>0]
df.Height.min()
# Out:
# 0.01

# %%
df.groupby('Rings')['Shucked weight'].mean()
# Out:
# Rings
# 1     0.001000
# 2     0.004500
# 3     0.011767
# 4     0.024719
# 5     0.061696
# 6     0.123413
# 7     0.182657
# 8     0.293927
# 9     0.387938
# 10    0.447217
# 11    0.503977
# 12    0.472781
# 13    0.434638
# 14    0.427190
# 15    0.402471
# 16    0.421716
# 17    0.467052
# 18    0.446833
# 19    0.440625
# 20    0.458115
# 21    0.447464
# 22    0.405000
# 23    0.399444
# 24    0.600250
# 25    0.426500
# 26    0.384000
# 27    0.539000
# 29    0.705500
# Name: Shucked weight, dtype: float64

# %%
df.groupby('Rings')['Shucked weight','Whole weight','Shell weight'].mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#        Shucked weight  Whole weight  Shell weight
# Rings
# 1            0.001000      0.002000      0.001500
# 2            0.004500      0.015000      0.005000
# 3            0.011767      0.028400      0.008933
# 4            0.024719      0.059605      0.018000
# 5            0.061696      0.125500      0.036770
# 6            0.123413      0.273713      0.077333
# 7            0.182657      0.397386      0.111648
# 8            0.293927      0.641128      0.178721
# 9            0.387938      0.852013      0.236509
# 10           0.447217      1.008748      0.282976
# 11           0.503977      1.142559      0.319866
# 12           0.472781      1.102904      0.321157
# 13           0.434638      1.075453      0.320828
# ...

# %%
import matplotlib.pyplot as plt

# %%
df.hist(figsize=(20,10), grid=False, layout=(2, 4), bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f41576673d0>,
# ...
#       dtype=object)

# %%
import seaborn as sns

# %%
sns.countplot(x = 'Sex', data = df, palette="Set3")

# %%
plt.figure(figsize = (20,7))
sns.swarmplot(x = 'Sex', y = 'Rings', data = df, hue = 'Sex')
sns.violinplot(x = 'Sex', y = 'Rings', data =df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 56.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 52.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 58.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
import numpy as np
num_features = df.select_dtypes(include=[np.number]).columns
sns.pairplot(df[num_features])

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df[num_features].corr(), annot=True)

# %%
var = 'Shell weight'
plt.scatter(x = df[var], y = df['Rings'],)
plt.grid(True)

# %%
df.drop(df[(df['Shell weight']> 0.6) & (df['Rings'] < 25)].index, inplace=True)
df.drop(df[(df['Shell weight']<0.8) & (df['Rings'] > 25)].index, inplace=True)

# %%
var = 'Shell weight'
plt.scatter(x = df[var], y = df['Rings'],)
plt.grid(True)

# %%
df.drop(df[(df['Shell weight']>0.8) & (df['Rings'] > 25)].index, inplace=True)
var = 'Shell weight'
plt.scatter(x = df[var], y = df['Rings'],)
plt.grid(True)

# %%
var = 'Viscera weight'
plt.scatter(x = df[var], y = df['Rings'],)
plt.grid(True)

# %%
df.drop(df[(df['Viscera weight']> 0.5) & (df['Rings'] < 20)].index, inplace=True)
df.drop(df[(df['Viscera weight']<0.5) & (df['Rings'] >= 25)].index, inplace=True)

# %%
var = 'Viscera weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)

# %%
var = 'Shucked weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Shucked weight']>= 1) & (df['Rings'] < 20)].index, inplace=True)
df.drop(df[(df['Shucked weight']<1) & (df['Rings'] > 20)].index, inplace=True)
var = 'Shucked weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)

# %%
var = 'Whole weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Whole weight']> 2.0) & (df['Rings'] <= 20)].index, inplace=True)
var = 'Whole weight'
plt.scatter(x = df[var], y = df['Rings'])
plt.grid(True)

# %%
var = 'Diameter'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Diameter']<=0.1) & (df['Rings']< 2.5)].index, inplace=True)
var = 'Diameter'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)

# %%
var = 'Height'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)

# %%
df.drop(df[(df['Height']>0.4) & (df['Rings'] < 15)].index, inplace=True)
var = 'Height'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)

# %%
var = 'Length'
plt.scatter(x = df[var], y =df['Rings'])
plt.grid(True)

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df[num_features].corr(), annot=True)
